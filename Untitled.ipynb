# %%
import yfinance as yf
import indicators
import plot
import neat_run
import neat
import pandas as pd
import cProfile
data = yf.download('AAPL', start='2022-01-01', end='2022-12-31')
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.953888
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  177.669983
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.943985
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  170.056961
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.225037
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.127075
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.307236
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.339409
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.889572
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.207779
#
#                Volume
# Date
# ...

# %%
def gen_ind(data):
    indicators.SMA(data,14)
    indicators.EMA(data,14)
    indicators.MOM(data,14)
    indicators.ROC(data,14)
    indicators.ATR(data,14)
    indicators.BBANDS(data,14)
    indicators.PPSR(data)
    indicators.PPSRFIBO(data)
    indicators.STOK(data)
    indicators.STO(data,14)
    indicators.TRIX(data,14)
    indicators.ADX(data,14,20)
    indicators.MACD(data)
    indicators.MASS(data)
    indicators.VORTEX(data,14)
    # indicators.KST(data,14)
    indicators.RSI(data,14)
    indicators.TSI(data, 25, 13)
    # indicators.ACCDIST(data,14)
    indicators.CHAIKIN(data)
    indicators.MFI(data,14)
    indicators.OBV(data,14)
    indicators.FORCE(data,14)
    indicators.EOM(data,14)
    indicators.CCI(data,14)
    indicators.COPP(data,14)
    indicators.KELCH(data,14)
    indicators.ULTOSC(data)
    indicators.DONCH(data,14)
    data = data.dropna()
    for x in ['Open','High','Low','Close', 'SMA_14','EMA_14','MOM_14','ROC_14','ATR_14','PP','S1','S2','S3','R1','R2','R3','R1fibo','S1fibo','R2fibo','S2fibo','R3fibo','S3fibo','KELCHmiddle_14','KELCHup_14','KELCHdown_14']:
        data[x+'_norm'] = data['Adj Close'] - data[x]
        data = data.drop(x, axis=1)
    
    return data

data.to_csv(r'stock_data.csv')
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.953888
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  177.669983
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.943985
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  170.056961
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.225037
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.127075
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.307236
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.339409
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.889572
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.207779
#
#                Volume
# Date
# 2022-01-03  104487900
# 2022-01-04   99310400
# 2022-01-05   94537600
# ...

# %%
# def get_market_movement(stock_data, neat_config):
#     # Define your NEAT configuration
#     config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
#                          neat.DefaultSpeciesSet, neat.DefaultStagnation, neat_config)

#     # Define your evaluation function
#     def evaluate_genome(genome, config):
#         net = neat.nn.FeedForwardNetwork.create(genome, config)
#         # Generate signals using NEAT-generated network
#         signals = neat_run.generate_signals(net, stock_data,14)  # Replace with your signal generation function
#         # Calculate return based on generated signals
#         _, _, final_return = neat_run.calculate_return(stock_data, signals)  # Replace with your return calculation function
#         return final_return

#     # Create a NEAT population
#     population = neat.Population(config)

#     # Run NEAT evolution for a certain number of generations
#     num_generations = 10  # Set the number of generations
#     for generation in range(num_generations):
#         for _, genome in population.population.items():
#             genome.fitness = evaluate_genome(genome, config)

#         # Evolve the population
#         population.run(lambda genomes, config: None, 1)  # Replace with your evolution mechanism

#     # Get the best genome after evolution
#     best_genome_id = max(population.population, key=lambda x: population.population[x].fitness)
#     best_genome = population.population[best_genome_id]

#     # Generate signals using the best genome
#     best_net = neat.nn.FeedForwardNetwork.create(best_genome, config)
#     best_signals = neat_run.generate_signals(best_net, stock_data)  # Replace with your signal generation function

#     # Optimize signals or apply strategies to maximize returns
#     optimized_signals = optimize_signals(best_signals)  # Implement your optimization strategy here

#     return optimized_signals

# signals = get_market_movement(data,"path_to_neat_config_file.txt")

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import yfinance as yf
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

tickers = ['LT.NS', 'NESTLEIND.NS', 'ASIANPAINT.NS', 'TATAMOTORS.NS', 'SBIN.NS', 'INDIANB.NS', 'RELIANCE.NS', 'CIPLA.NS', 'WIPRO.NS', 'IRCTC.NS']
data_list = []

# Download and preprocess data for all tickers
for ticker in tickers:
    data = yf.download(ticker, start='2021-09-01', end='2021-12-31')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

for ticker in tickers:
    data = yf.download(ticker, start='2021-05-01', end='2021-08-31')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

for ticker in tickers:
    data = yf.download(ticker, start='2021-01-01', end='2021-04-30')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

for ticker in tickers:
    data = yf.download(ticker, start='2022-09-01', end='2022-12-31')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

for ticker in tickers:
    data = yf.download(ticker, start='2022-05-01', end='2022-08-31')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

for ticker in tickers:
    data = yf.download(ticker, start='2022-01-01', end='2022-04-30')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

for ticker in tickers:
    data = yf.download(ticker, start='2023-09-01', end='2023-12-31')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

for ticker in tickers:
    data = yf.download(ticker, start='2023-05-01', end='2023-08-31')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

for ticker in tickers:
    data = yf.download(ticker, start='2023-01-01', end='2023-04-30')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)

# Determine the maximum number of components needed across all tickers
max_components = 0

for data in data_list:
    # Standardize the features
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(data)
    
    # Apply PCA to capture 95% of the variance
    pca = PCA()
    principal_components = pca.fit_transform(scaled_features)
    
    # Find the number of components that explain 95% of the variance
    explained_variance_ratio_cumsum = pca.explained_variance_ratio_.cumsum()
    n_components = (explained_variance_ratio_cumsum >= 0.98).argmax() + 1
    
    # Update max_components if the current number is greater
    max_components = max(max_components, n_components)

# Apply PCA with the maximum number of components for all tickers
# pca_data_list = []

# for data in data_list:
#     # Standardize the features
#     scaler = StandardScaler()
#     scaled_features = scaler.fit_transform(data)
    
#     # Apply PCA with the maximum number of components
#     pca = PCA(n_components=max_components)
#     principal_components = pca.fit_transform(scaled_features)
    
#     # Create a DataFrame with the principal components
#     columns = [f'PC{i+1}' for i in range(max_components)]
#     principal_df = pd.DataFrame(data=principal_components, columns=columns, index=data.index)
    
#     pca_data_list.append(principal_df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_27972\2249620444.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[x+'_norm'] = data['Adj Close'] - data[x]
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_27972\2249620444.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[x+'_norm'] = data['Adj Close'] - data[x]
# ...

# %%
import time
import math
start = time.time()
# cProfile.run('winning_net, best_average_return = neat_run.run_multiple_datasets(14, 7, data_list, max_components)')
winning_net, best_average_return = neat_run.run_multiple_datasets(14, 50, data_list, max_components)
end = time.time()
tt = math.modf((end - start)/3600)
print("Execution time: "+str(int(tt[1]))+" hours and "+str(int(tt[0]*60))+" minutes")
# Out:
# Generation 1:
# Best average return in Generation 1: 0.032195005026162904
# Generation 2:
# Best average return in Generation 2: 0.038566954139390715
# Generation 3:
# Best average return in Generation 3: 0.03866676466739303
# Generation 4:
# Best average return in Generation 4: 0.04097787198129263
# Generation 5:
# Best average return in Generation 5: 0.04097787198129263
# ...

# %%
tickers = ['LT.NS', 'NESTLEIND.NS', 'ASIANPAINT.NS', 'TATAMOTORS.NS', 'SBIN.NS', 'INDIANB.NS', 'RELIANCE.NS', 'CIPLA.NS', 'WIPRO.NS', 'IRCTC.NS']
data_list = []

# Download and preprocess data for all tickers
for ticker in tickers:
    data = yf.download(ticker, start='2022-05-01', end='2022-12-24')
    data = gen_ind(data)  # Assuming you have a 'gen_ind' function
    data_list.append(data)
    
for data in data_list:
    if 'Adj Close' in data.columns:
        all_days_data = data.drop('Adj Close', axis=1)
        all_days_data = all_days_data.values
    else:
        all_days_data = data.values
    test_signals = neat_run.generate_signals_with_pca(winning_net, all_days_data, 14, max_components)
    test_daily_returns, test_cumulative_returns, test_final_return = neat_run.calculate_return(data, test_signals)
    adj_close = data['Adj Close']
    print("Cumulative Final Return on Test Data:", test_final_return, " Buy and Hold Return: " + str(adj_close[-1] / adj_close[14] - 1))
    plot.plot(data, test_signals, test_cumulative_returns)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_27972\2249620444.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[x+'_norm'] = data['Adj Close'] - data[x]
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_27972\2249620444.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[x+'_norm'] = data['Adj Close'] - data[x]
# ...

# %%
data = yf.download('SBIN.NS', start='2022-05-01', end='2022-12-24')
data = gen_ind(data)
# scaler = StandardScaler()
# scaled_features = scaler.fit_transform(data)

# # Apply PCA with the maximum number of components
# pca = PCA(n_components=max_components)
# principal_components = pca.fit_transform(scaled_features)

# # Create a DataFrame with the principal components
# columns = [f'PC{i+1}' for i in range(max_components)]
# principal_df = pd.DataFrame(data=principal_components, columns=columns, index=data.index)

if 'Adj Close' in data.columns:
    all_days_data = data.drop('Adj Close', axis=1)
    all_days_data = all_days_data.values
else:
    all_days_data = data.values
test_signals = neat_run.generate_signals_with_pca(winning_net, all_days_data, 14, max_components)
test_daily_returns, test_cumulative_returns, test_final_return = neat_run.calculate_return(data, test_signals)
adj_close = data['Adj Close']
print("Cumulative Final Return on Test Data:", test_final_return, " Buy and Hold Return: " + str(adj_close[-1] / adj_close[14] - 1))
plot.plot(data, test_signals, test_cumulative_returns)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_27972\2249620444.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[x+'_norm'] = data['Adj Close'] - data[x]
# Cumulative Final Return on Test Data: 0.19095306017031768  Buy and Hold Return: 0.19745486835801263

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import argrelextrema

data = yf.download('INDIANB.NS', start='2022-05-01', end='2022-12-24')
data = gen_ind(data)

# Assuming 'Adj Close' column is available in your DataFrame
# Replace 'your_stock_data.csv' with the actual file name or provide the data in another way
df = data

# Calculate rate of change (ROC)
df['ROC'] = df['Adj Close'].pct_change()

# Define a function to dynamically adjust the window size based on ROC
def dynamic_window_size(roc):
    if (roc < 0.01).all():
        return 1
    elif ((0.01 <= roc) & (roc < 0.012)).any():
        return 2
    elif ((0.012 <= roc) & (roc < 0.016)).any():
        return 4
    else:
        return 7

# Identify peaks and troughs with dynamically adjusted window size
df['Peak'] = df['Adj Close'].iloc[argrelextrema(df['Adj Close'].values, comparator=lambda x, y: x > y, order=dynamic_window_size(df['ROC']))[0]]
df['Trough'] = df['Adj Close'].iloc[argrelextrema(df['Adj Close'].values, comparator=lambda x, y: x < y, order=dynamic_window_size(df['ROC']))[0]]

# Initialize the 'test_signals' list
test_signals = [0] * len(df)

# Generate buy and sell signals
buy_indices = [df.index.get_loc(idx) for idx in df.index[df['Trough'].notnull()]]
sell_indices = [df.index.get_loc(idx) for idx in df.index[df['Peak'].notnull()]]

for idx in buy_indices:
    test_signals[idx] = 1

for idx in sell_indices:
    test_signals[idx] = -1

# Plot the data with buy and sell signals
test_daily_returns, test_cumulative_returns, test_final_return = neat_run.calculate_return(data, test_signals)
adj_close = data['Adj Close']
print("Cumulative Final Return on Test Data:", test_final_return, " Buy and Hold Return: " + str(adj_close[-1] / adj_close[14] - 1))
plot.plot(data, test_signals, test_cumulative_returns)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_27972\2249620444.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[x+'_norm'] = data['Adj Close'] - data[x]
# Cumulative Final Return on Test Data: 1.24828615500742  Buy and Hold Return: 0.5997052661432825
